# %%
import pandas as pd
pd.read_csv("C:/Users/NANDAKISHORE BOINI/OneDrive/Desktop/sales_data_with_discounts.csv")
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
sales=pd.read_csv("C:/Users/NANDAKISHORE BOINI/OneDrive/Desktop/sales_data_with_discounts.csv")

# %%
sales.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
sales.shape
# Out:
# (450, 13)

# %%
import statistics as st

# %%
total_sales=sales['Total Sales Value']
type(total_sales)
# Out:
# pandas.core.series.Series

# %%
st.mean(total_sales)
# Out:
# 33812.83555555555

# %%
st.median(total_sales)
# Out:
# 5700.0

# %%
st.mode(total_sales)
# Out:
# 24300

# %%
st.variance(total_sales)
# Out:
# 2553793721.625459

# %%
st.stdev(total_sales)
# Out:
# 50535.07417255326

# %%
vol=sales['Volume']
type(vol)
# Out:
# pandas.core.series.Series

# %%
st.mean(vol)
# Out:
# 5.066666666666666

# %%
st.median(vol)
# Out:
# 4.0

# %%
st.mode(vol)
# Out:
# 3

# %%
st.variance(vol)
# Out:
# 17.906458797327396

# %%
st.stdev(vol)
# Out:
# 4.231602391213923

# %%
avg=sales['Avg Price']
type(avg)
# Out:
# pandas.core.series.Series

# %%
st.mean(avg)
# Out:
# 10453.433333333332

# %%
st.median(avg)
# Out:
# 1450.0

# %%
st.mode(avg)
# Out:
# 8100

# %%
st.variance(avg)
# Out:
# 326882959.02115816

# %%
st.stdev(avg)
# Out:
# 18079.90483993647

# %%
dr=sales['Discount Rate (%)']
type(dr)
# Out:
# pandas.core.series.Series

# %%
st.mean(dr)
# Out:
# 15.155241895330914

# %%
st.median(dr)
# Out:
# 16.57776564929597

# %%
st.mode(dr)
# Out:
# 11.654820286277229

# %%
st.variance(dr)
# Out:
# 17.813482536655926

# %%
st.stdev(dr)
# Out:
# 4.220602153325509

# %%
da=sales['Discount Amount']
type(da)
# Out:
# pandas.core.series.Series

# %%
st.mean(da)
# Out:
# 3346.499424342415

# %%
st.median(da)
# Out:
# 988.9337332382784

# %%
st.mode(da)
# Out:
# 21153.49881959317

# %%
st.variance(da)
# Out:
# 20339224.738869175

# %%
st.stdev(da)
# Out:
# 4509.9029633539985

# %%
nsv=sales['Net Sales Value']
type(nsv)
# Out:
# pandas.core.series.Series

# %%
st.mean(nsv)
# Out:
# 30466.336131270138

# %%
st.median(nsv)
# Out:
# 4677.788059301853

# %%
st.mode(nsv)
# Out:
# 160346.50118040683

# %%
st.variance(nsv)
# Out:
# 2149125043.9881463

# %%
st.stdev(nsv)
# Out:
# 46358.65662406695

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(x='Volume',data=sales)
plt.xlabel('volume')
skewness = sales['Volume'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: 2.731723626557714'

# %%
plt.boxplot(sales['Volume'])
Q1 = sales['Volume'].quantile(0.25)
Q3 = sales['Volume'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Volume'] < lower_bound) | (sales['Volume'] > upper_bound)]

# %%
plt.hist(x='Avg Price',data=sales)
skewness = sales['Avg Price'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: 1.9088730767759727'

# %%
plt.boxplot(sales['Avg Price'])
Q1 = sales['Avg Price'].quantile(0.25)
Q3 = sales['Avg Price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Avg Price'] < lower_bound) | (sales['Avg Price'] > upper_bound)]

# %%
plt.hist(x='Total Sales Value',data=sales)
skewness = sales['Total Sales Value'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: 1.5347293238977937'

# %%
plt.boxplot(sales['Total Sales Value'])
Q1 = sales['Total Sales Value'].quantile(0.25)
Q3 = sales['Total Sales Value'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Total Sales Value'] < lower_bound) | (sales['Total Sales Value'] > upper_bound)]

# %%
plt.hist(x='Discount Rate (%)',data=sales)
skewness = sales['Discount Rate (%)'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: -1.0622943696988825'

# %%
plt.boxplot(sales['Discount Rate (%)'])
Q1 = sales['Discount Rate (%)'].quantile(0.25)
Q3 = sales['Discount Rate (%)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Discount Rate (%)'] < lower_bound) | (sales['Discount Rate (%)'] > upper_bound)]

# %%
plt.hist(x='Discount Amount',data=sales)
skewness = sales['Discount Amount'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: 1.9130377339538271'

# %%
plt.boxplot(sales['Discount Amount'])
Q1 = sales['Discount Amount'].quantile(0.25)
Q3 = sales['Discount Amount'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Discount Amount'] < lower_bound) | (sales['Discount Amount'] > upper_bound)]

# %%
plt.hist(x='Net Sales Value',data=sales)
skewness = sales['Net Sales Value'].skew()
(f"Skewness: {skewness}")
# Out:
# 'Skewness: 1.5408217575344376'

# %%
plt.boxplot(sales['Net Sales Value'])
Q1 = sales['Net Sales Value'].quantile(0.25)
Q3 = sales['Net Sales Value'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = sales[(sales['Net Sales Value'] < lower_bound) | (sales['Net Sales Value'] > upper_bound)]

# %%
import pandas as pd
sales=pd.read_csv("C:/Users/NANDAKISHORE BOINI/OneDrive/Desktop/sales_data_with_discounts.csv")
sales.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
 import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar(x='Date',height=sales['Total Sales Value'],data=sales)
plt.xticks(rotation=45) 
plt.xlabel('dates')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.bar(x='Day',height=sales['Total Sales Value'],data=sales)
plt.xlabel('days')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.bar(x='SKU',height=sales['Total Sales Value'],data=sales)
plt.xticks(rotation=90)
plt.xlabel('sku')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.bar(x='City',height=sales['Total Sales Value'],data=sales)
plt.xlabel('city')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.bar(x='Brand',height=sales['Total Sales Value'],data=sales)
plt.xlabel('brands')
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
plt.bar(x='Model',height=sales['Total Sales Value'],data=sales)
plt.xlabel('models')
plt.xticks(rotation=90)
plt.ylabel('sales')
# Out:
# Text(0, 0.5, 'sales')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sales=pd.read_csv("C:/Users/NANDAKISHORE BOINI/OneDrive/Desktop/sales_data_with_discounts.csv")
sales.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
numeric_columns = ['Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

plt.figure(figsize=(12, 6))

for col in numeric_columns:
    plt.plot(sales[col], label=col)

plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Sales Data Columns')
plt.legend()
plt.show()

# %%
numeric_columns = ['Volume','Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

for col in numeric_columns:
    plt.figure(figsize=(10, 4))
    plt.plot(sales[col])
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title(f'{col}')
    plt.show()

# %%
from scipy.stats import zscore
# List of numeric columns to apply z-score
numeric_columns = ['Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# Apply z-score normalization
sales[numeric_columns] = sales[numeric_columns].apply(lambda x: zscore(x))

# Display the first few rows to verify
print(sales.head())
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0   0.091173           2.925721          -0.830289         3.952816
# 1  -0.019570           1.330995          -0.852661         1.849014
# 2   0.312659           1.562775          -1.351631         1.622995
# 3   0.534146           1.719276          -1.949723         1.113807
# 4  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value
# 0         2.804756
# 1         1.271026
# 2         1.545675
# 3         1.765810
# 4        -0.227595

# %%
numeric_columns = ['Volume','Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
for col in numeric_columns:
    sales[col] = zscore(sales[col])

# Display the first few rows to verify
print(sales.head())
# Out:
#          Date       Day  SKU City    Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C  2.350029  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C  1.167129  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C  0.457388  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C  0.220808  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C -0.488932  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0   0.091173           2.925721          -0.830289         3.952816
# 1  -0.019570           1.330995          -0.852661         1.849014
# 2   0.312659           1.562775          -1.351631         1.622995
# 3   0.534146           1.719276          -1.949723         1.113807
# 4  -0.130313          -0.188452           0.673739         0.227852
#
#    Net Sales Value
# 0         2.804756
# 1         1.271026
# 2         1.545675
# 3         1.765810
# 4        -0.227595

# %%
numeric_columns = ['Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
for col in numeric_columns:
    sales[col] = zscore(sales[col])

# Plotting z-score values
plt.figure(figsize=(12, 6))

# Plot each numeric column
for col in numeric_columns:
    plt.plot(sales[col], label=col)

# Adding labels and title
plt.xlabel('Index')
plt.ylabel('Z-Score')
plt.title('Z-Score of Various Sales Data Columns')
plt.legend()
plt.show()

# %%
for col in numeric_columns:
    sales[col] = zscore(sales[col])
numeric_columns = ['Volume','Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
# Plotting each z-score column separately
for col in numeric_columns:
    plt.figure(figsize=(10, 4))
    plt.plot(sales[col])
    plt.xlabel('Index')
    plt.ylabel('Z-Score')
    plt.title(f'Z-Score of {col}')
    plt.show()

# %%
import pandas as pd

# Sample data
df = pd.DataFrame(sales)

# Before One-Hot Encoding
print("Before One-Hot Encoding:")
print(df)

# Apply one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Volume','Avg Price','Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value'])

# After One-Hot Encoding
print("After One-Hot Encoding:")
print(df_encoded)
# Out:
# Before One-Hot Encoding:
#            Date       Day  SKU City    Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C  2.350029    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C  1.167129    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C  0.457388    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C  0.220808    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C -0.488932    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...       ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C -0.725512  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C  0.220808  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C -0.725512  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C -0.488932  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C -0.962092  Lifestyle  Jeera     M-Shoes
#
# ...
